# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiaraVanderputten/lab10DS/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

db= pd.read_csv("https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/2D_gauss_clusters.txt")

x= db.loc[:,'x']
y=db.loc[:,'y']

plt.figure(figsize=(10,10))
plt.scatter(x,y)
